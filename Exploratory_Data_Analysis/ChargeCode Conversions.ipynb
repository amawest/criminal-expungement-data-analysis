# %%
import os
import pandas as pd
os.chdir('/Users/amawest/Desktop/')
circuit = pd.read_csv("circuit_criminal_2019.csv")
# circuit = pd.read_csv("../Data/circuit_criminal_2019.csv")

# %%
circuit[['Charge','CodeSection']].head(5)
# Out:
#                            Charge CodeSection
# 0       VIOL PROBATION ON FEL OFF    19.2-306
# 1       GRAND LARCENY: AUTO THEFT     18.2-95
# 2  ENTER HOUSE TO COMMIT A&B ETC.     18.2-91
# 3      DRUGS: POSSESS SCH I OR II    18.2-250
# 4               SHOW CAUSE MOTION    18.2-456

# %%
len(circuit.CodeSection.unique())
# Out:
# 787

# %%
x = circuit.groupby(['Charge','CodeSection']).size().reset_index(name="Count").sort_values(by=['Count'], ascending=False)
x
# Out:
#                               Charge CodeSection  Count
# 12751      VIOL PROBATION ON FEL OFF    19.2-306   7064
# 2143                     BOND APPEAL    19.2-124   1531
# 9704             PROBATION VIOLATION    19.2-306   1439
# 9083    POSS.OF CONTROLLED SUBSTANCE    18.2-250   1421
# 6740                   GRAND LARCENY     18.2-95   1004
# ...                              ...         ...    ...
# 4942       DRIVING REVOKED - 7TH OFF  B.46.2-301      1
# 4943   DRIVING REVOKED / 2ND OFFENSE  B.46.2-301      1
# 4944           DRIVING REVOKED / 4TH  B.46.2-301      1
# 4945             DRIVING REVOKED 4TH  B.46.2-301      1
# 13041               ZONING VIOLATION    19.1-347      1
#
# [13042 rows x 3 columns]

# %%
# This simply creates a copy of the charge and charge code, 
# drops duplicates and keeps the first instance of the charge description.
# because there are SO many different charge codes, we are just using the 
# first instance, but it would be more accurate to go and manually label all of the 
# charge codes to be the most accurate.
x = x.drop_duplicates(subset='CodeSection', keep="first")
x = x.rename(columns={"Charge": "CodeSection_Description"})
x
# Out:
#               CodeSection_Description  CodeSection  Count
# 12751       VIOL PROBATION ON FEL OFF     19.2-306   7064
# 2143                      BOND APPEAL     19.2-124   1531
# 9083     POSS.OF CONTROLLED SUBSTANCE     18.2-250   1421
# 6740                    GRAND LARCENY      18.2-95   1004
# 7928   OBTAIN MONEY FALSE PRET >=$200     18.2-178    717
# ...                               ...          ...    ...
# 4804                DRIVE VIOL CURFEW  46.2-334.01      1
# 4807       DRIVE W/COMM LIC DISQUALIF  46.2-341.21      1
# 5093                  DRUNK IN PUBLIC       28-147      1
# 4906      DRIVING IN SAFETY WORK ZONE     46.2-814      1
# 13041                ZONING VIOLATION     19.1-347      1
#
# [786 rows x 3 columns]

# %%
# Now we merge the data back together, with "CodeSection_Description"
# being 1:1 with each charge code (versus there being many "charge" instances for each charge code)
result = pd.merge(x, circuit, on="CodeSection")
result
# Out:
#            CodeSection_Description  CodeSection  Count HearingDate  \
# 0        VIOL PROBATION ON FEL OFF     19.2-306   7064  2019-12-17
# 1        VIOL PROBATION ON FEL OFF     19.2-306   7064  2019-12-12
# 2        VIOL PROBATION ON FEL OFF     19.2-306   7064  2019-12-12
# 3        VIOL PROBATION ON FEL OFF     19.2-306   7064  2019-12-12
# 4        VIOL PROBATION ON FEL OFF     19.2-306   7064  2019-12-12
# ...                            ...          ...    ...         ...
# 78027            DRIVE VIOL CURFEW  46.2-334.01      1  2019-11-26
# 78028   DRIVE W/COMM LIC DISQUALIF  46.2-341.21      1  2019-01-03
# 78029              DRUNK IN PUBLIC       28-147      1  2019-10-25
# 78030  DRIVING IN SAFETY WORK ZONE     46.2-814      1  2019-09-11
# 78031             ZONING VIOLATION     19.1-347      1  2019-03-11
#
#                       HearingResult HearingJury HearingPlea  \
# 0      Revoked - Sentence/Probation         NaN         NaN
# 1      Revoked - Sentence/Probation         NaN      Guilty
# 2      Revoked - Sentence/Probation         NaN      Guilty
# 3      Revoked - Sentence/Probation         NaN      Guilty
# 4      Revoked - Sentence/Probation         NaN      Guilty
# ...                             ...         ...         ...
# 78027                Nolle Prosequi         NaN         NaN
# 78028                     Sentenced         NaN      Guilty
# 78029                     Dismissed         NaN         NaN
# 78030                     Sentenced         NaN         NaN
# 78031                     Dismissed         NaN         NaN
#
#                   HearingType HearingRoom  fips  ... DrivingRestrictions  \
# 0                  Revocation         NaN    91  ...                 NaN
# 1                      Capias         NaN    99  ...                 NaN
# 2                      Capias         NaN    99  ...                 NaN
# 3                      Capias         NaN    99  ...                 NaN
# 4                        Bond         NaN    99  ...                 NaN
# ...                       ...         ...   ...  ...                 ...
# 78027                    Plea          2C   107  ...                 NaN
# 78028                    Plea         NaN   179  ...                 NaN
# 78029  Defendant Adjudication         10A    13  ...                 NaN
# 78030                   Trial         10C    13  ...                 NaN
# 78031     Further Disposition           3    41  ...                 NaN
#
#       RestrictionEffectiveDate RestrictionEndDate VAAlcoholSafetyAction  \
# 0                          NaN                NaN                   NaN
# 1                          NaN                NaN                   NaN
# 2                          NaN                NaN                   NaN
# 3                          NaN                NaN                   NaN
# 4                          NaN                NaN                   NaN
# ...                        ...                ...                   ...
# 78027                      NaN                NaN                   NaN
# 78028                      NaN                NaN                   NaN
# 78029                      NaN                NaN                   NaN
# 78030                      NaN                NaN                   NaN
# 78031                      NaN                NaN                   NaN
#
#       RestitutionPaid RestitutionAmount Military TrafficFatality AppealedDate  \
# 0                 NaN               0.0      NaN             NaN          NaN
# 1                 NaN               0.0      NaN             NaN          NaN
# 2                 NaN               NaN      NaN             NaN          NaN
# 3                 NaN               NaN      NaN             NaN          NaN
# 4                 NaN               0.0      NaN             NaN          NaN
# ...               ...               ...      ...             ...          ...
# 78027             NaN               NaN      NaN               f          NaN
# 78028             NaN               NaN      NaN               f          NaN
# 78029             NaN               NaN      NaN             NaN          NaN
# 78030             NaN               0.0      NaN               f          NaN
# 78031             NaN               NaN      NaN               f          NaN
#
#           person_id
# 0      9.318000e+13
# 1      2.703000e+13
# 2      2.703000e+13
# 3      2.703000e+13
# 4      2.750100e+14
# ...             ...
# 78027  2.701700e+14
# 78028  1.031200e+14
# 78029  2.301810e+14
# 78030  6.619000e+13
# 78031  2.320700e+14
#
# [78032 rows x 52 columns]

# %%
# How we'll label everything
result['code_and_desc'] = result['CodeSection'] + ', ' + result['CodeSection_Description']

# %%
result.head(2)
# Out:
#      CodeSection_Description CodeSection  Count HearingDate  \
# 0  VIOL PROBATION ON FEL OFF    19.2-306   7064  2019-12-17
# 1  VIOL PROBATION ON FEL OFF    19.2-306   7064  2019-12-12
#
#                   HearingResult HearingJury HearingPlea HearingType  \
# 0  Revoked - Sentence/Probation         NaN         NaN  Revocation
# 1  Revoked - Sentence/Probation         NaN      Guilty      Capias
#
#   HearingRoom  fips  ... RestrictionEffectiveDate RestrictionEndDate  \
# 0         NaN    91  ...                      NaN                NaN
# 1         NaN    99  ...                      NaN                NaN
#
#   VAAlcoholSafetyAction RestitutionPaid RestitutionAmount Military  \
# 0                   NaN             NaN               0.0      NaN
# 1                   NaN             NaN               0.0      NaN
#
#   TrafficFatality AppealedDate     person_id  \
# 0             NaN          NaN  9.318000e+13
# 1             NaN          NaN  2.703000e+13
#
#                          code_and_desc
# 0  19.2-306, VIOL PROBATION ON FEL OFF
# 1  19.2-306, VIOL PROBATION ON FEL OFF
#
# [2 rows x 53 columns]
